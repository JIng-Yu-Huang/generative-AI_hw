# %% [markdown]
# <a href="https://colab.research.google.com/github/JIng-Yu-Huang/generative-AI_hw/blob/main/0506%E5%9C%A8colab%E4%B8%8A%E4%BD%BF%E7%94%A8fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 情境設定**
# 為我的學術個人網站製作圖片— 網頁圖示、個人大頭照(插圖化)、研究展示插圖
# 風格走甜美可愛、溫柔、學術感

# %% [markdown]
# # **2. 三張圖的詳細設定 & 簡短說明**
# |  | 圖片名稱       | Prompt  | Fooocus 功能 | 心得                         |
# | :--: | ---------- | --------------------------- | ---------- | -------------------------------- |
# | 1   | 網站圖示   | a cute west highland white terrier<br> is typing on laptop| Aspect Ratios: 1024*1024<br>Input Image: 在Image Prompt 中放入參考照片<br>Weight:調整到1.226<br>Advanced: Style選Flat 2D Art +Misc Kawaii<br>   | 我給他一張美樂蒂在打電腦的圖片<br>，希望把美樂蒂改成西高地狗<br>權重調小的時候(0.4)，會直接是一隻真實的狗坐在電腦上；<br>把權重調大之後，狗狗的形象會比較像原本圖片的風格的卡通狗，跟我想要的比較一致 |
# | 2   | 個人大頭照   | a young and cute taiwanese girl,<br> smile happily, chestnut-brown hair,<br> big loose waves | Aspect Ratios: 768*1280<br> Input Image: 在Outpaint 中放入我的照片，<br>(原本有勾選Enable Advanced Masking Features和<br>Invert Mask When Generating，Mask generation model<br> 選擇Sam，Detection prompt選hair，改變頭髮顏色和捲度，<br>之後效果不佳，所以移除這個過程)<br>Advanced: Style選 Fooocus Pony+SAI Anime   | 我其實是希望他可以把我真實的照片變成插圖化，<br>看起來不要像是真人，要像是卡通人物，<br>但是了很多風格的結果，發現不是會把我變成另一個真人，<br>不然就是太像AI的真人，跟老師demo的範例效果不一樣，<br>我所以之後改成用image Prompt，直接讓她生出的圖跟我給的圖片更相近，<br>試了近百次，還是沒有特別滿意的，從中挑了其中一張作為代表 |
# | 3   | 研究展示插圖 | a computer with math formula <br>on the screen, black fixation dots and <br>saccade lines, academic but cute. | Aspect Ratios: 960*1088<br>Advanced: Style選Ads Real Estate+Fooocus Semi Realistic | ControlNet-Canny＋Outpaint |

# %% [markdown]
# **-目標設定**
# 把自己的照片插畫化，希望保留真實度，但有卡通風
#
# **-素材準備**
# 1. 自己的照片 1 張
# 2. 初始 prompt：a young and cute taiwanese girl, smile happily, chestnut-brown hair, big loose waves
#
# **-開始生成生成**
# 選擇各類可愛的風格來回切換
# 問題：生成結果會變成另一個真人，或是太像AI的人
#
# **-調整與改善**
# 策略調整改成用image Prompt，直接讓她生出的圖跟我給的圖片更相近
# 每次不滿意都會微調 prompt
#
# **-選擇圖片**
# 試了近百次，還是沒有特別滿意的
# 從中挑了風格是Fooocus Pony+SAI Anime生成的圖片作為代表

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 41.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 23.67 MiB/s, done.
# Resolving deltas: 100% (3855/3855), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
