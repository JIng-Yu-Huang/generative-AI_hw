# %% [markdown]
# <a href="https://colab.research.google.com/github/JIng-Yu-Huang/generative-AI_hw/blob/main/0422%E5%88%A9%E7%94%A8Bing%E9%80%B2%E8%A1%8C%E6%96%87%E5%AD%97%E7%94%9F%E5%9C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌳 四季森林系眼鏡女孩系列--利用Bing進行文字生圖
# ### 學號：61308001E
# ### 系級：資教所 碩一
# ### 姓名：黃靖妤
# ### 使用風格：
#   2D simple illustration style with clean line art and soft pastel colors, minimal shading, gentle smiling expression, forestcore cute theme, Japanese style.
#   -->使用 2D 簡約插畫風格，線條乾淨俐落，色彩柔和偏粉彩色系，幾乎沒有陰影。
# 角色表情溫柔帶著微笑，整體呈現森林系可愛主題，並帶有日系插畫的風格。
#
#
# ### **以下四組圖分別對應春、夏、秋、冬的戴眼鏡女孩~**

# %% [markdown]
# 🌸 春天 Spring <a name="spring"></a>
#
# **Prompt 使用：**
# `A cute forest girl with glasses picking wildflowers in a blooming spring meadow, cherry blossoms flying in the air, 2D simple illustration, clean line art, soft pastel colors, minimal shading.`
#
# **生成圖片：**

# %%
from IPython.display import Image, display
display(Image(filename='./spring.jpg'))

# %% [markdown]
# ☀️ 夏 Summer <a name="summer"></a>
#
# **Prompt 使用：**
# `A cheerful forest girl with glasses hiking through a sunny forest, wearing a straw hat and a light dress, carrying a picnic basket, 2D simple illustration, clean line art, soft pastel colors, minimal shading`
#
# **生成圖片：**

# %%
from IPython.display import Image, display
display(Image(filename='./summer.jpg'))

# %% [markdown]
# 🍁 秋 Autumn <a name="autumn"></a>
#
# **Prompt 使用：**
# `A gentle forest girl with glasses walking on a path covered in red and orange autumn leaves, wearing a knitted sweater and boots, holding a cup of hot tea, 2D simple illustration, clean line art, soft pastel colors, minimal shading`
#
# **生成圖片：**

# %%
from IPython.display import Image, display
display(Image(filename='./fall.jpg'))

# %% [markdown]
# ❄️ 冬 Winter <a name="winter"></a>
#
# **Prompt 使用：**
# `A shy forest girl with glasses sitting by a snow-covered tree, wearing a fluffy scarf and mittens, snow gently falling, glowing lantern beside her, 2D simple illustration, clean line art, soft pastel colors, minimal shading`
#
# **生成圖片：**

# %%
from IPython.display import Image, display
display(Image(filename='./winter.jpg'))

# %% [markdown]
# ## ✨ 本次作業心得
#
# - 春天、夏天的圖片一次就生成出符合我想像的風格，幾乎不需要重試
# - 但是秋天的圖片嘗試了十幾次才終於生出一張風格與我想像一致的圖片；冬天的圖片也花了好幾次嘗試才選到比較符合我喜歡的風格的版本
# - 我覺得Bing目前最大的限制是：即使我們描述得很細很清楚，它也不一定能精準理解我心中喜歡且想要的風格，因為用語言描述跟實際生成出來之間會有一定程度的落差
# - 如果Bing能加入「使用者反饋系統」（例如：標記哪些照片風格自己喜歡或不喜歡），就能幫助模型更快知道我們真正想要的風格。未來在生成時，就可以少花很多時間重打prompt，效率也會大大提升！
#
# ---
