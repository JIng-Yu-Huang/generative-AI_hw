# %% [markdown]
# <a href="https://colab.research.google.com/github/JIng-Yu-Huang/generative-AI_hw/blob/main/0304hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **3/14作業**
#
# 用styleGAN生成圖片
#
# 1. This X does not exist：生成人像
#
# ![0304.png](data:image/png;base64,...)
#
# 2. Pix2Pix：自己畫貓咪的輪廓，生成真實貓咪
#
# ![0304-2.png](data:image/png;base64,...)

# %% [markdown]
# Q2.為何現在較少人用StyleGAN? 而是Diffusion Models?
#
# **StyleGAN:**
